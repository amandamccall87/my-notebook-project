# %%
60 * 60
seconds_per_hour = 3600

# %%
seconds_per_hour * 24
seconds_per_day = seconds_per_hour * 24

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# Yes, the integer division result (24) agreed with the floating-point value (24.0) aside from the final .0.
